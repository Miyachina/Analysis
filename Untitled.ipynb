# %%
import pandas as pd

# %%
import numpy as np
from pandas import Series, DataFrame
import matplotlib as mlb
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
kill=pd.read_csv('killings.csv')

# %%
kill.head()
# Out:
#    uid               name age gender           raceethnicity    month  day  \
# 0    2    Matthew Ajibade  22   Male                   Black  January    1
# 1    4       Lewis Lembke  47   Male                   White  January    2
# 2    7        Tim Elliott  53   Male  Asian/Pacific Islander  January    2
# 3    5  Michael Kocher Jr  19   Male                   White  January    3
# 4    6      John Quintero  23   Male         Hispanic/Latino  January    3
#
#    year         streetaddress       city state     classification  \
# 0  2015  1050 Carl Griffin Dr   Savannah    GA   Death in custody
# 1  2015  4505 SW Masters Loop      Aloha    OR            Gunshot
# 2  2015  600 E Island Lake Dr    Shelton    WA            Gunshot
# 3  2015    2600 Kaumualii Hwy  Kaumakani    HI  Struck by vehicle
# 4  2015  500 North Oliver Ave    Wichita    KS            Gunshot
#
#                  lawenforcementagency    armed
# 0     Chatham County Sheriff's Office       No
# ...

# %%
kill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1145 entries, 0 to 1144
# Data columns (total 14 columns):
# uid                     1145 non-null int64
# name                    1145 non-null object
# age                     1145 non-null object
# gender                  1145 non-null object
# raceethnicity           1145 non-null object
# month                   1145 non-null object
# day                     1145 non-null int64
# year                    1145 non-null int64
# streetaddress           1139 non-null object
# city                    1145 non-null object
# state                   1145 non-null object
# classification          1145 non-null object
# lawenforcementagency    1145 non-null object
# armed                   1145 non-null object
# dtypes: int64(3), object(11)
# memory usage: 125.3+ KB

# %%
spread=kill['state'].value_counts()

# %%
a=spread.columns=['State','Nos']

# %%
spread
# Out:
# CA    211
# TX    110
# FL     71
# AZ     44
# GA     39
# OK     38
# OH     37
# CO     32
# LA     28
# NC     26
# NY     25
# PA     24
# WA     23
# VA     23
# IL     23
# NJ     23
# MO     22
# NM     21
# IN     21
# SC     21
# TN     21
# MI     20
# NV     19
# AL     19
# KY     19
# MD     17
# OR     17
# MN     13
# MS     12
# WI     12
# WV     12
# KS     11
# UT     10
# MA     10
# NE      9
# ID      8
# DC      6
# WY      6
# HI      5
# AR      5
# AK      5
# IA      5
# MT      4
# CT      4
# DE      4
# NH      3
# ME      2
# SD      2
# ND      1
# RI      1
# VT      1
# Name: state, dtype: int64

# %%
a
# Out:
# ['State', 'Nos']

# %%
a=DataFrame(spread)

# %%
a[:3]
# Out:
#     state
# CA    211
# TX    110
# FL     71

# %%
b=kill.groupby('state')

# %%
print b

# %%
a.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C89F160>]],
#       dtype=object)

# %%
a.reset_index(level=0, inplace=True)

# %%
a
# Out:
#    index  state
# 0     CA    211
# 1     TX    110
# 2     FL     71
# 3     AZ     44
# 4     GA     39
# 5     OK     38
# 6     OH     37
# 7     CO     32
# 8     LA     28
# 9     NC     26
# 10    NY     25
# 11    PA     24
# 12    WA     23
# 13    VA     23
# 14    IL     23
# 15    NJ     23
# 16    MO     22
# 17    NM     21
# 18    IN     21
# 19    SC     21
# 20    TN     21
# 21    MI     20
# 22    NV     19
# 23    AL     19
# 24    KY     19
# 25    MD     17
# 26    OR     17
# 27    MN     13
# 28    MS     12
# 29    WI     12
# 30    WV     12
# 31    KS     11
# 32    UT     10
# 33    MA     10
# 34    NE      9
# 35    ID      8
# 36    DC      6
# 37    WY      6
# 38    HI      5
# 39    AR      5
# 40    AK      5
# 41    IA      5
# 42    MT      4
# 43    CT      4
# 44    DE      4
# 45    NH      3
# 46    ME      2
# 47    SD      2
# 48    ND      1
# 49    RI      1
# 50    VT      1

# %%
sns.factorplot('state', data=kill, kind='count')

# %%
a.rename(columns={'index':'state','state':'Nos'})
# Out:
#     level_0 state  Nos
# 0         0    CA  211
# 1         1    TX  110
# 2         2    FL   71
# 3         3    AZ   44
# 4         4    GA   39
# 5         5    OK   38
# 6         6    OH   37
# 7         7    CO   32
# 8         8    LA   28
# 9         9    NC   26
# 10       10    NY   25
# 11       11    PA   24
# 12       12    WA   23
# 13       13    VA   23
# 14       14    IL   23
# 15       15    NJ   23
# 16       16    MO   22
# 17       17    NM   21
# 18       18    IN   21
# 19       19    SC   21
# 20       20    TN   21
# 21       21    MI   20
# 22       22    NV   19
# 23       23    AL   19
# 24       24    KY   19
# 25       25    MD   17
# 26       26    OR   17
# 27       27    MN   13
# 28       28    MS   12
# 29       29    WI   12
# 30       30    WV   12
# 31       31    KS   11
# 32       32    UT   10
# 33       33    MA   10
# 34       34    NE    9
# 35       35    ID    8
# 36       36    DC    6
# 37       37    WY    6
# 38       38    HI    5
# ...

# %%
sns.factorplot('state',data=a, kind='count')

# %%
kill.head()
# Out:
#    uid               name age gender           raceethnicity    month  day  \
# 0    2    Matthew Ajibade  22   Male                   Black  January    1
# 1    4       Lewis Lembke  47   Male                   White  January    2
# 2    7        Tim Elliott  53   Male  Asian/Pacific Islander  January    2
# 3    5  Michael Kocher Jr  19   Male                   White  January    3
# 4    6      John Quintero  23   Male         Hispanic/Latino  January    3
#
#    year         streetaddress       city state     classification  \
# 0  2015  1050 Carl Griffin Dr   Savannah    GA   Death in custody
# 1  2015  4505 SW Masters Loop      Aloha    OR            Gunshot
# 2  2015  600 E Island Lake Dr    Shelton    WA            Gunshot
# 3  2015    2600 Kaumualii Hwy  Kaumakani    HI  Struck by vehicle
# 4  2015  500 North Oliver Ave    Wichita    KS            Gunshot
#
#                  lawenforcementagency    armed
# 0     Chatham County Sheriff's Office       No
# ...

# %%
sns.factorplot('age',data=kill,kind='count', size=8,aspect=8)

# %%
kill.head()

# %%
kill
